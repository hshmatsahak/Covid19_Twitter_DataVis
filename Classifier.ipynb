# %%
import ast
import pandas as pd
maskinhashtag_df = pd.read_csv('./Stored_Dataframes/MaskDFs/maskinhashtag_df.csv', low_memory=False, lineterminator='\n')
postwts_df = pd.read_csv('./Stored_Dataframes/MaskDFs/postwts_hashtag_df.csv', low_memory=False, lineterminator='\n')
negtwts_df = pd.read_csv('./Stored_Dataframes/MaskDFs/negtwts_hashtag_df.csv', low_memory=False, lineterminator='\n')

# %%
sample_df = maskinhashtag_df.sample(n=100)
for _, row in sample_df.iterrows():
    print(row['text'])
    print(row['posneg_hashtag'])
    print("\n")
# Out:
# This lady was waiting in line to vote...with her BLACK SON! Doing her best to keep him safe on a few levels! Prayers and strength to this amazing mother and American! #GoVote #WearAMask https://t.co/H2fVih1krv
# positive
#
#
# "...getting the #shot will not be your cue to take off your #mask and run free into a crowded bar. The end of the #pandemic will be an #evolution, not a #revolution, the #vaccine just another powerful tool in that process." #coronavirus #COVIDー19
# https://t.co/eJkUTRzmZf
# neutral
#
#
# Do you guys think if we stop calling them “face masks” and start calling them facial border walls that more people will start wearing them. Just spitballing here. #Biden2020 #COVIDー19 #facemask
# neutral
#
#
# I’m embarrassed to be a #texan today.... #WearAMask https://t.co/AERyO7L2oE
# positive
#
#
# https://t.co/vvG6oPUHWn
# #Covid19 #ARDS💀 d-dimer 4070;RV dilatation w 1.2×1.2 cm Clot in transit in RV w/in TV chordae &amp; severe TR s/p TPA
# @CASEfromASE @ASE360
# ...
